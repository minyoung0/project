# %%
import csv

f=open('서비스 세로.csv',encoding='cp949')#파일 열기
data=csv.reader(f)
header=next(data) #데이터의 헤더를 재낌(순번, 지역, 센터 적힌거 사라짐)

year=2013

#child 리스트 모음
child=[]
child2014=[]
child2015=[]
child2016=[]
child2017=[]
child2018=[]
child2019=[]

#trash 리스트 모음
trash=[]
trash2014=[]
trash2015=[]
trash2016=[]
trash2017=[]
trash2018=[]
trash2019=[]

#parents 리스트 모음
parents=[]
parents2014=[]
parents2015=[]
parents2016=[]
parents2017=[]
parents2018=[]
parents2019=[]
for i in data:
    if i[0]==str(year):
        if '아동' in i[1]:
            for k in range(3,13):
                child.append(int(i[k]))
        elif '행위자' in i[1]:
            for k in range(3,13):
                trash.append(int(i[k]))
        elif '부모및가족' in i[1]:
            for k in range(3,13):
                parents.append(int(i[k]))
    elif i[0]==str(year+1):
        if '아동' in i[1]:
            for k in range(3,13):
                child2014.append(int(i[k]))
        elif '행위자' in i[1]:
            for k in range(3,13):
                trash2014.append(int(i[k]))
        elif '부모및가족' in i[1]:
            for k in range(3,13):
                parents2014.append(int(i[k]))
    elif i[0]==str(year+2):
        if '아동' in i[1]:
            for k in range(3,13):
                child2015.append(int(i[k]))
        elif '행위자' in i[1]:
            for k in range(3,13):
                trash2015.append(int(i[k]))
        elif '부모및가족' in i[1]:
            for k in range(3,13):
                parents2015.append(int(i[k]))
    elif i[0]==str(year+3):
        if '아동' in i[1]:
            for k in range(3,13):
                child2016.append(int(i[k]))
        elif '행위자' in i[1]:
            for k in range(3,13):
                trash2016.append(int(i[k]))
        elif '부모및가족' in i[1]:
            for k in range(3,13):
                parents2016.append(int(i[k]))
    elif i[0]==str(year+4):
        if '아동' in i[1]:
            for k in range(3,13):
                child2017.append(int(i[k]))
        elif '행위자' in i[1]:
            for k in range(3,13):
                trash2017.append(int(i[k]))
        elif '부모및가족' in i[1]:
            for k in range(3,13):
                parents2017.append(int(i[k]))
    elif i[0]==str(year+5):
        if '아동' in i[1]:
            for k in range(3,13):
                child2018.append(int(i[k]))
        elif '행위자' in i[1]:
            for k in range(3,13):
                trash2018.append(int(i[k]))
        elif '부모및가족' in i[1]:
            for k in range(3,13):
                parents2018.append(int(i[k]))
    elif i[0]==str(year+6):
        if '아동' in i[1]:
            for k in range(3,13):
                child2019.append(int(i[k]))
        elif '행위자' in i[1]:
            for k in range(3,13):
                trash2019.append(int(i[k]))
        elif '부모및가족' in i[1]:
            for k in range(3,13):
                parents2019.append(int(i[k]))
print(child2014)
print(trash2014)
print(parents2014)
# Out:
# [165234, 6182, 34397, 103342, 0, 1877, 0, 0, 256, 10890]
# [62686, 3214, 5418, 1508, 0, 0, 0, 0, 0, 991]
# [68859, 754, 5345, 2319, 0, 0, 0, 0, 0, 1883]

# %%
# from matplotlib import pyplot as plt
# from matplotlib import pyplot
# from matplotlib import font_manager,rc
# import matplotlib.pyplot as plt
# import numpy as np
# font_name=font_manager.FontProperties(fname="C:/Windows/Fonts/malgun.ttf").get_name()
# rc('font',family=font_name)
# plt.rcParams['figure.figsize']=[20,5]
# x_name=['상담','의료지원','심리치료지원','가족기능강화','학습 및 보호지원','사건처리지원','행위자수탁프로그램','피해아동수탁프로그램','일시보호서비스','기타']

a_bottom=np.add(consulting_child,medical_child)
b_bottom=np.add(a_bottom,psychotherapy_child)
c_bottom=np.add(b_bottom,function_child)
d_bottom=np.add(c_bottom,study_child)
e_bottom=np.add(d_bottom,case_child)
f_bottom=np.add(e_bottom,a_consignment_child)
g_bottom=np.add(f_bottom,c_consignment_child)
h_bottom=np.add(g_bottom,temporary_child)
i_bottom=np.add(h_bottom,etc_child)



# x=range(len(x_name))
# y=range(len(x_name))

# W_=0.1
# pyplot.bar(range(len(child)),child,width=W_)
# pyplot.bar([i+W_ for i in range(len(trash))],child2014,width=W_)
# pyplot.bar([i-W_ for i in range(len(parents))],parents,width=W_)
# pyplot.xlabel=x_name

# plt.bar(x,child)
# plt.bar(x,child2014,bottom=child)
# plt.bar(x,child2015,bottom=a_bottom)
# plt.bar(x,child2016,bottom=b_bottom)
# plt.bar(x,child2017,bottom=c_bottom)
# plt.bar(x,child2018,bottom=d_bottom)
# plt.bar(x,child2019,bottom=e_bottom)
# plt.bar(y,trash)
# plt.bar(y,trash2014,bottom=trash)
# plt.bar(y,trash2015,bottom=f_bottom)
# plt.bar(y,trash2016,bottom=g_bottom)
# plt.bar(y,trash2017,bottom=h_bottom)
# plt.bar(y,trash2018,bottom=i_bottom)
# plt.bar(y,trash2019,bottom=j_bottom)


# ax=plt.subplot()
# ax.set_xticks(y)
# # ax.set_xtictlabels(x_name)
# # plt.xlabel(x_name)
# plt.show()

# %%
from matplotlib import pyplot as plt
from matplotlib import pyplot
from matplotlib import font_manager,rc
import matplotlib.pyplot as plt
import numpy as np


n = 1  # This is our first dataset (out of 2)
t = 3 # Number of dataset
d = 11 # Number of sets of bars
w = 0.8 # Width of each bar

store1_x = [t*element + w*n for element in range(d)]
plt.bar(store1_x, child2014)

n = 2  # This is our second dataset (out of 2)
t = 3 # Number of dataset
d = 11 # Number of sets of bars
w = 0.8 # Width of each bar

store2_x = [t*element + w*n for element in range(d)]
plt.bar(store2_x, trash)

n = 3  # This is our second dataset (out of 3)
t = 3 # Number of dataset
d = 11 # Number of sets of bars
w = 0.8 # Width of each bar

store3_x = [t*element + w*n for element in range(d)]
plt.bar(store3_x,parents)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-8-491748c526ab> in <module>
#      12
#      13 store1_x = [t*element + w*n for element in range(d)]
# ---> 14 plt.bar(store1_x, child2014)
#      15
#      16 n = 2  # This is our second dataset (out of 2)
#
# ~\anaconda3\lib\site-packages\matplotlib\pyplot.py in bar(x, height, width, bottom, align, data, **kwargs)
#    2485         x, height, width=0.8, bottom=None, *, align='center',
#    2486         data=None, **kwargs):
# -> 2487     return gca().bar(
#    2488         x, height, width=width, bottom=bottom, align=align,
#    2489         **({"data": data} if data is not None else {}), **kwargs)
#
# ~\anaconda3\lib\site-packages\matplotlib\__init__.py in inner(ax, data, *args, **kwargs)
#    1436     def inner(ax, *args, data=None, **kwargs):
#    1437         if data is None:
# ...
