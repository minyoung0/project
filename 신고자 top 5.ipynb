# %%
import csv
import operator
import matplotlib.pyplot as plt
from matplotlib import font_manager,rc
import matplotlib.pyplot as plt
plt.rcParams['figure.figsize']=[15,5]
f=open('신고자통합.csv',encoding='cp949')#파일 열기
data=csv.reader(f)
header=next(data) #데이터의 헤더를 재낌(순번, 지역, 센터 적힌거 사라짐)
header=next(data)
header=next(data)

font_name=font_manager.FontProperties(fname="C:/Windows/Fonts/malgun.ttf").get_name()
rc('font',family=font_name)

name_list=[]
y2015_list=[]
y2016_list=[]
y2017_list=[]
y2018_list=[]
y2019_list=[]
new_list=[]
year=2015
alist=[]

for i in data:
    name_list.append(i[0])
    y2015_list.append(int(i[1]))
    y2016_list.append(int(i[2]))
    y2017_list.append(int(i[3]))
    y2018_list.append(int(i[4]))
    y2019_list.append(int(i[5]))
dict_2015=dict(zip(name_list,y2015_list))
dict_2016=dict(zip(name_list,y2016_list))
dict_2017=dict(zip(name_list,y2017_list))
dict_2018=dict(zip(name_list,y2018_list))
dict_2019=dict(zip(name_list,y2019_list))
    

alist=[dict_2015,dict_2016,dict_2017,dict_2018,dict_2019]
for k in alist:
    new_list=sorted(k.items(),key=lambda k:k[1], reverse=True )
    print(year,'년도 신고자 top5: ', new_list[:5],"\n")
    year+=1
# plt.pie(y2015_list[:5],labels=new_list[:5] , autopct='%.1f%%')
# Out:
# 2015 년도 신고자 top5:  [('사회복지관련종사자', 3590), ('부모', 3048), ('일반상담', 2465), ('교직원', 2172), ('아동본인', 1500)]
#
# 2016 년도 신고자 top5:  [('부모', 4619), ('사회복지관련종사자', 4088), ('교직원', 3978), ('일반상담', 3604), ('아동본인', 2322)]
#
# 2017 년도 신고자 top5:  [('아동보호전문기관장과 종사자', 6881), ('부모', 5328), ('교직원', 5168), ('아동본인', 3883), ('일반상담', 2951)]
#
# 2018 년도 신고자 top5:  [('아동보호전문기관장과 종사자', 7756), ('교직원', 6406), ('부모', 6089), ('아동본인', 4512), ('일반상담', 2464)]
#
# 2019 년도 신고자 top5:  [('아동보호전문기관장과 종사자', 12389), ('부모', 6506), ('교직원', 5901), ('아동본인', 4752), ('일반상담', 2560)]

# %%
# import matplotlib.pyplot as plt
# from matplotlib import font_manager,rc
# import matplotlib.pyplot as plt
# plt.rcParams['figure.figsize']=[20,5]

# # font_location='C:/Windows/Fonts/malgun.ttf'
# # font_name=fm.FontProperties(fname=font_location).get_name()
# font_name=font_manager.FontProperties(fname="C:/Windows/Fonts/malgun.ttf").get_name()
# rc('font',family=font_name)
# # matplotlib.rc('font',family=font_name)
# plt.title('신고자 유형',fontsize=40)
# name_list=['부모','사회복지관련 종사자','일반상담','아동본인','교직원','아동보호전문기관종사자',]
# plt.plot(name_list,[3048,3590,2465,1500,2172,0],label='2015')
# plt.plot(name_list,[3604,4088,3604,2322,3978,619],label='2016')
# plt.plot(name_list,[5328,323,2951,3883,5168,6881],label='2017')
# plt.plot(name_list,[5089,275,2464,4512,6406,7756],label='2018')
# plt.plot(name_list,[6506,959,2560,4752,5901,12389],label='2019')
# plt.legend(loc='upper right')

# %%
import matplotlib.pyplot as plt
from matplotlib import font_manager,rc
import matplotlib.pyplot as plt
plt.rcParams['figure.figsize']=[20,5]
# font_location='C:/Windows/Fonts/malgun.ttf'
# font_name=fm.FontProperties(fname=font_location).get_name()
font_name=font_manager.FontProperties(fname="C:/Windows/Fonts/malgun.ttf").get_name()
rc('font',family=font_name)
# matplotlib.rc('font',family=font_name)
plt.title('신고자 유형',fontsize=40)
name_list=['2015','2016','2017','2018','2019']
plt.plot(name_list,[3048,4619,5328,6089,6506],label='부모')
plt.plot(name_list,[3590,4088,323,275,959],label='사회복지관련 종사자')
plt.plot(name_list,[2465,3604,2951,2464,2560],label='일반상담')
plt.plot(name_list,[1500,2322,3883,4512,4752],label='아동본인')
plt.plot(name_list,[2172,3978,5168,6406,5901],label='교직원')
plt.plot(name_list,[0,619,6881,7756,12389],label='아동보호전문기관종사자')
plt.legend(loc='upper left')
