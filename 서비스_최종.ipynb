# %%
import csv

f=open('피해아동__학대행위자__부모_및_가족에_대한_서비스_제공_데이터병합_20210420095449.csv',encoding='cp949')#파일 열기
data=csv.reader(f)
header=next(data)
header=next(data)
header=next(data)

consulting_child =[]
consulting_trash=[]
consulting_parents=[]
medical_child =[]
medical_trash =[]
medical_parents =[]
psychotherapy_child = []
psychotherapy_trash = []
psychotherapy_parents = []
function_child = []
function_trash = []
function_parents = []
study_child = []
study_trash = []
study_parents = []
case_child = []
case_trash = []
case_parents = []
a_consignment_child = []
a_consignment_trash = []
a_consignment_parents = []
c_consignment_child = []
c_consignment_trash = []
c_consignment_parents = []
temporary_child =[]
temporary_trash =[]
temporary_parents =[]
etc_child = []
etc_trash = []
etc_parents = []

for i in data:
    if '상담' in i[0]:
        for k in range(1,20,3):
            consulting_child.append(int(i[k]))
        for k in range(2,21,3):
            consulting_trash.append(int(i[k])) 
        for k in range(3,22,3):
            consulting_parents.append(int(i[k]))            
    elif '의료지원' in i[0]:
        for k in range(1,20,3):
            medical_child.append(int(i[k]))
        for k in range(2,21,3):
            medical_trash.append(int(i[k])) 
        for k in range(3,22,3):
            medical_parents.append(int(i[k]))
    elif '심리치료지원' in i[0]:
        for k in range(1,20,3):
            psychotherapy_child.append(int(i[k]))
        for k in range(2,21,3):
            psychotherapy_trash.append(int(i[k])) 
        for k in range(3,22,3):
            psychotherapy_parents.append(int(i[k]))
    elif '가족기능강화' in i[0]:
        for k in range(1,20,3):
            function_child.append(int(i[k]))
        for k in range(2,21,3):
            function_trash.append(int(i[k])) 
        for k in range(3,22,3):
            function_parents.append(int(i[k]))
    elif '학습 및 보호지원' in i[0]:
        for k in range(1,20,3):
            study_child.append(int(i[k]))
        for k in range(2,21,3):
            study_trash.append(int(i[k])) 
        for k in range(3,22,3):
            study_parents.append(int(i[k]))       
    elif '사건처리지원' in i[0]:
        for k in range(1,20,3):
            case_child.append(int(i[k]))
        for k in range(2,21,3):
            case_trash.append(int(i[k])) 
        for k in range(3,22,3):
            case_parents.append(int(i[k]))      
    elif '행위자수탁프로그램' in i[0]:
        for k in range(1,20,3):
            a_consignment_child.append(int(i[k]))
        for k in range(2,21,3):
            a_consignment_trash.append(int(i[k])) 
        for k in range(3,22,3):
            a_consignment_parents.append(int(i[k]))        
    elif '피해아동수탁프로그램' in i[0]:
        for k in range(1,20,3):
            c_consignment_child.append(int(i[k]))
        for k in range(2,21,3):
            c_consignment_trash.append(int(i[k])) 
        for k in range(3,22,3):
            c_consignment_parents.append(int(i[k]))        
    elif '일시보호서비스' in i[0]:
        for k in range(1,20,3):
            temporary_child.append(int(i[k]))
        for k in range(2,21,3):
            temporary_trash.append(int(i[k])) 
        for k in range(3,22,3):
            temporary_parents.append(int(i[k]))       
    elif '기타' in i[0]:
        for k in range(1,20,3):
            etc_child.append(int(i[k]))
        for k in range(2,21,3):
            etc_trash.append(int(i[k])) 
        for k in range(3,22,3):
            etc_parents.append(int(i[k]))
            
a_bottom=np.add(consulting_child,medical_child)
b_bottom=np.add(a_bottom,psychotherapy_child)
c_bottom=np.add(b_bottom,function_child)
d_bottom=np.add(c_bottom,study_child)
e_bottom=np.add(d_bottom,case_child)
f_bottom=np.add(e_bottom,a_consignment_child)
g_bottom=np.add(f_bottom,c_consignment_child)
h_bottom=np.add(g_bottom,temporary_child)
i_bottom=np.add(h_bottom,etc_child)

aa_bottom=np.add(consulting_trash,medical_trash)
bb_bottom=np.add(aa_bottom,psychotherapy_trash)
cc_bottom=np.add(bb_bottom,function_trash)
dd_bottom=np.add(cc_bottom,study_trash)
ee_bottom=np.add(dd_bottom,case_trash)
ff_bottom=np.add(ee_bottom,a_consignment_trash)
gg_bottom=np.add(ff_bottom,c_consignment_trash)
hh_bottom=np.add(gg_bottom,temporary_trash)
ii_bottom=np.add(hh_bottom,etc_trash)

aaa_bottom=np.add(consulting_parents,medical_parents)
bbb_bottom=np.add(aaa_bottom,psychotherapy_parents)
ccc_bottom=np.add(bbb_bottom,function_parents)
ddd_bottom=np.add(ccc_bottom,study_parents)
eee_bottom=np.add(ddd_bottom,case_parents)
fff_bottom=np.add(eee_bottom,a_consignment_parents)
ggg_bottom=np.add(fff_bottom,c_consignment_parents)
hhh_bottom=np.add(ggg_bottom,temporary_parents)
iii_bottom=np.add(hhh_bottom,etc_parents)

# %%
from matplotlib import pyplot as plt
from matplotlib import pyplot
from matplotlib import font_manager,rc
import matplotlib.pyplot as plt
import numpy as np

plt.rcParams['figure.figsize']=[40,20]
font_name=font_manager.FontProperties(fname="C:/Windows/Fonts/malgun.ttf").get_name()
rc('font',family=font_name)

topic=['2013','2014','2015','2016','2017','2018','2019']

n = 1  # This is our first dataset (out of 2)
t = 3 # Number of dataset
d = 7 # Number of sets of bars
w = 0.8 # Width of each bar

store1_x = [t*element + w*n for element in range(d)]
plt.bar(store1_x,consulting_child,color='darksalmon',edgecolor='black',label='상담')

n = 2  # This is our second dataset (out of 2)
t = 3 # Number of dataset
d = 7 # Number of sets of bars
w = 0.8 # Width of each bar

store2_x = [t*element + w*n for element in range(d)]
plt.bar(store2_x,consulting_trash,color='darksalmon',edgecolor='black')

n = 3  # This is our second dataset (out of 3)
t = 3 # Number of dataset
d = 7 # Number of sets of bars
w = 0.8 # Width of each bar

store3_x = [t*element + w*n for element in range(d)]
plt.bar(store3_x,consulting_parents,color='darksalmon',edgecolor='black')

plt.bar(store1_x,medical_child,bottom=consulting_child,color='salmon',edgecolor='black',label='의료지원')
plt.bar(store1_x,psychotherapy_child,bottom=a_bottom,color='khaki',edgecolor='black',label='심리치료지원')
plt.bar(store1_x,function_child,bottom=b_bottom,color='lightgreen',edgecolor='black',label='가족기능강화')
plt.bar(store1_x,study_child,bottom=c_bottom,color='powderblue',edgecolor='black',label='학습 및 보호지원')
plt.bar(store1_x,case_child,bottom=d_bottom,color='steelblue',edgecolor='black',label='사건처리지원')
plt.bar(store1_x,a_consignment_child,bottom=e_bottom,color='mediumpurple',edgecolor='black',label='행위자수탁프로그램')
plt.bar(store1_x,c_consignment_child,bottom=f_bottom,color='rebeccapurple',edgecolor='black',label='피해아동수탁프로그램')
plt.bar(store1_x,temporary_child,bottom=g_bottom,color='lightpink',edgecolor='black',label='일시보호서비스')
plt.bar(store1_x,etc_child,bottom=h_bottom,color='orchid',edgecolor='black',label='기타')

plt.bar(store2_x,medical_trash,bottom=consulting_trash,color='salmon',edgecolor='black')
plt.bar(store2_x,psychotherapy_trash,bottom=aa_bottom,color='khaki',edgecolor='black')
plt.bar(store2_x,function_trash,bottom=bb_bottom,color='lightgreen',edgecolor='black')
plt.bar(store2_x,study_trash,bottom=cc_bottom,color='powderblue',edgecolor='black')
plt.bar(store2_x,case_trash,bottom=dd_bottom,color='steelblue',edgecolor='black')
plt.bar(store2_x,a_consignment_trash,bottom=ee_bottom,color='mediumpurple',edgecolor='black')
plt.bar(store2_x,c_consignment_trash,bottom=ff_bottom,color='rebeccapurple',edgecolor='black')
plt.bar(store2_x,temporary_trash,bottom=gg_bottom,color='lightpink',edgecolor='black')
plt.bar(store2_x,etc_trash,bottom=hh_bottom,color='orchid',edgecolor='black')

plt.bar(store3_x,medical_parents,bottom=consulting_parents,color='salmon',edgecolor='black')
plt.bar(store3_x,psychotherapy_parents,bottom=aaa_bottom,color='khaki',edgecolor='black')
plt.bar(store3_x,function_parents,bottom=bbb_bottom,color='lightgreen',edgecolor='black')
plt.bar(store3_x,study_parents,bottom=ccc_bottom,color='powderblue',edgecolor='black')
plt.bar(store3_x,case_parents,bottom=ddd_bottom,color='steelblue',edgecolor='black')
plt.bar(store3_x,a_consignment_parents,bottom=eee_bottom,color='mediumpurple',edgecolor='black')
plt.bar(store3_x,c_consignment_parents,bottom=fff_bottom,color='rebeccapurple',edgecolor='black')
plt.bar(store3_x,temporary_parents,bottom=ggg_bottom,color='lightpink',edgecolor='black')
plt.bar(store3_x,etc_parents,bottom=hhh_bottom,color='orchid',edgecolor='black')
# plt.bar(store1_x,case_child,bottom=d_bottom)

# middile_x=[(a+b+c)/3 for (a,b,c) in zip(store1,store2,store3)]
plt.title('아동학대 관련 서비스',fontsize=100)
ax=plt.subplot()
ax.set_xticks(store2_x)
ax.set_xticklabels(topic,fontsize=40)
ax.set_yticklabels([0,100000,200000,300000,400000,500000,600000,700000],fontsize=30)
plt.legend(loc='upper left',fontsize=32)
# Out:
# <ipython-input-4-c2f19f0ba1cd>:70: MatplotlibDeprecationWarning: Adding an axes using the same arguments as a previous axes currently reuses the earlier instance.  In a future version, a new instance will always be created and returned.  Meanwhile, this warning can be suppressed, and the future behavior ensured, by passing a unique label to each axes instance.
#   ax=plt.subplot()
# <ipython-input-4-c2f19f0ba1cd>:73: UserWarning: FixedFormatter should only be used together with FixedLocator
#   ax.set_yticklabels([0,100000,200000,300000,400000,500000,600000,700000],fontsize=30)
